# %%
pip install nltk==3.3
# Out:
# Requirement already satisfied: nltk==3.3 in c:\programdata\anaconda3\lib\site-packages (3.3)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from nltk==3.3) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk

# %%
nltk.download('twitter_samples')
# Out:
# [nltk_data] Downloading package twitter_samples to C:\Users\Salahuddin
# [nltk_data]     Ahammad\AppData\Roaming\nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# True

# %%
from nltk.corpus import twitter_samples

# %%
positive_tweets = twitter_samples.strings('positive_tweets.json')

# %%
negative_tweets = twitter_samples.strings('negative_tweets.json')

# %%
text = twitter_samples.strings('tweets.20150430-223406.json')

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Salahuddin
# [nltk_data]     Ahammad\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
positive_tweets = twitter_samples.strings('positive_tweets.json')

# %%
negative_tweets = twitter_samples.strings('negative_tweets.json')

# %%
text = twitter_samples.strings('tweets.20150430-223406.json')

# %%
tweet_tokens = twitter_samples.tokenized('positive_tweets.json')

# %%
print(tweet_tokens)
# Out:
# [['#FollowFriday', '@France_Inte', '@PKuchly57', '@Milipol_Paris', 'for', 'being', 'top', 'engaged', 'members', 'in', 'my', 'community', 'this', 'week', ':)'], ['@Lamb2ja', 'Hey', 'James', '!', 'How', 'odd', ':/', 'Please', 'call', 'our', 'Contact', 'Centre', 'on', '02392441234', 'and', 'we', 'will', 'be', 'able', 'to', 'assist', 'you', ':)', 'Many', 'thanks', '!'], ['@DespiteOfficial', 'we', 'had', 'a', 'listen', 'last', 'night', ':)', 'As', 'You', 'Bleed', 'is', 'an', 'amazing', 'track', '.', 'When', 'are', 'you', 'in', 'Scotland', '?', '!'], ['@97sides', 'CONGRATS', ':)'], ['yeaaaah', 'yippppy', '!', '!', '!', 'my', 'accnt', 'verified', 'rqst', 'has', 'succeed', 'got', 'a', 'blue', 'tick', 'mark', 'on', 'my', 'fb', 'profile', ':)', 'in', '15', 'days'], ['@BhaktisBanter', '@PallaviRuhail', 'This', 'one', 'is', 'irresistible', ':)', '#FlipkartFashionFriday', 'http://t.co/EbZ0L2VENM'], ['We', "don't", 'like', 'to', 'keep', 'our', 'lovely', 'customers', 'waiting', 'for', 'long', '!', 'We', 'hope', 'you', 'enjoy', '!', 'Happy', 'Friday', '!', '-', 'LWWF', ':)', 'https://t.co/smyYriipxI'], ['@Impatientraider', 'On', 'second', 'thought', ',', 'there', '’', 's', 'just', 'not', 'enough', 'time', 'for', 'a', 'DD', ':)', 'But', 'new', 'shorts', 'entering', 'system', '.', 'Sheep', 'must', 'be', 'buying', '.'], ['Jgh', ',', 'but', 'we', 'have', 'to', 'go', 'to', 'Bayan', ':D', 'bye'], ['As', 'an', 'act', 'of', 'mischievousness', ',', 'am', 'calling', 'the', 'ETL', 'layer', 'of', 'our', 'in-house', 'warehousing', 'app', 'Katamari', '.', 'Well', '…', 'as', 'the', 'name', 'implies', ':p', '.'], ['#FollowFriday', '@wncer1', '@Defense_gouv', 'for', 'being', 'top', 'influencers', 'in', 'my', 'community', 'this', 'week', ':)'], ['Who', "Wouldn't", 'Love', 'These', 'Big', '...', 'Juicy', '...', 'Selfies', ':)', '-', 'http://t.co/QVzjgd1uFo', 'http://t.co/oWBL11eQRY'], ['@Mish23615351', 'follow', '@jnlazts', '&', 'http://t.co/RCvcYYO0Iq', 'follow', 'u', 'back', ':)'], ['@jjulieredburn', 'Perfect', ',', 'so', 'you', 'already', 'know', "what's", 'waiting', 'for', 'you', ':)'], ['Great', 'new', 'opportunity', 'for', 'junior', 'triathletes', 'aged', '12', 'and', '13', 'at', 'the', 'Gatorade', 'series', '!', 'Get', 'your', 'entries', 'in', ':)', 'http://t.co/of3DyOzML0'], ['Laying', 'out', 'a', 'greetings', 'card', 'range', 'for', 'print', 'today', '-', 'love', 'my', 'job', ':-)'], ["Friend's", 'lunch', '...', 'yummmm', ':)', '#Nostalgia', '#TBS', '#KU', '.'], ['@RookieSenpai', '@arcadester', 'it', 'is', 'the', 'id', 'conflict', 'thanks', 'for', 'the', 'help', ':D', "here's", 'the', 'screenshot', 'of', 'it', 'working'], ['@oohdawg_', 'Hi', 'liv', ':)', ')'], ['Hello', 'I', 'need', 'to', 'know', 'something', 'can', 'u', 'fm', 'me', 'on', 'Twitter', '?', '?', '—', 'sure', 'thing', ':)', 'dm', 'me', 'x', 'http://t.co/W6Dy130BV7'], ['#FollowFriday', '@MBandScott_', '@Eric_FLE', '@pointsolutions3', 'for', 'being', 'top', 'new', 'followers', 'in', 'my', 'community', 'this', 'week', ':)'], ['@rossbreadmore', "I've", 'heard', 'the', 'Four', 'Seasons', 'is', 'pretty', 'dope', '.', 'Penthouse', ',', 'obvs', '#Gobigorgohome', 'Have', 'fun', "y'all", ':)'], ['@gculloty87', 'Yeah', 'I', 'suppose', 'she', 'was', 'lol', '!', 'Chat', 'in', 'a', 'bit', 'just', 'off', 'out', 'x', ':)', ')'], ['Hello', ':)', 'Get', 'Youth', 'Job', 'Opportunities', 'follow', '>', '>', '@tolajobjobs', '@maphisa301'], ['💅', '🏽', '💋', '-', ':)', ')', ')', "haven't", 'seen', 'you', 'in', 'years'], ['@Bosslogic', '@amellywood', '@CW_Arrow', '@ARROWwriters', 'Thank', 'you', '!', ':-)'], ['@johngutierrez1', 'hope', 'the', 'rest', 'of', 'your', 'night', 'goes', 'by', 'quickly', '...', 'I', 'am', 'off', 'to', 'bed', '...', 'got', 'my', 'music', 'fix', 'and', 'now', 'it', 'is', 'time', 'to', 'dream', ':)'], ['Spiritual', 'Ritual', 'Festival', '(', 'Népal', ')', 'Beginning', 'of', 'Line-up', ':)', 'It', 'is', 'left', 'for', 'the', 'line-up', '(', 'y', ')', 'See', 'more', 'at', ':', '...', 'http:// ...

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Salahuddin
# [nltk_data]     Ahammad\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Salahuddin
# [nltk_data]     Ahammad\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
from nltk.tag import pos_tag

# %%
from nltk.corpus import twitter_samples

# %%
tweet_tokens = twitter_samples.tokenized('positive_tweets.json')

# %%
print(pos_tag(tweet_tokens[0]))
# Out:
# [('#FollowFriday', 'JJ'), ('@France_Inte', 'NNP'), ('@PKuchly57', 'NNP'), ('@Milipol_Paris', 'NNP'), ('for', 'IN'), ('being', 'VBG'), ('top', 'JJ'), ('engaged', 'VBN'), ('members', 'NNS'), ('in', 'IN'), ('my', 'PRP$'), ('community', 'NN'), ('this', 'DT'), ('week', 'NN'), (':)', 'NN')]

# %%
from nltk.stem.wordnet import WordNetLemmatizer

# %%
def lemmatize_sentence(tokens):
    lemmatizer = WordNetLemmatizer()
    lemmatized_sentence = []
    for word, tag in pos_tag(tokens):
        if tag.startswith('NN'):
            pos = 'n'
        elif tag.startswith('VB'):
            pos = 'v'
        else:
            pos = 'a'
        lemmatized_sentence.append(lemmatizer.lemmatize(word, pos))
    return lemmatized_sentence

print(lemmatize_sentence(tweet_tokens[0]))
# Out:
# ['#FollowFriday', '@France_Inte', '@PKuchly57', '@Milipol_Paris', 'for', 'be', 'top', 'engage', 'member', 'in', 'my', 'community', 'this', 'week', ':)']

# %%
import re, string

# %%
def remove_noise(tweet_tokens, stop_words = ()):

    cleaned_tokens = []

    for token, tag in pos_tag(tweet_tokens):
        token = re.sub('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+#]|[!*\(\),]|'\
                       '(?:%[0-9a-fA-F][0-9a-fA-F]))+','', token)
        token = re.sub("(@[A-Za-z0-9_]+)","", token)
        
        token = re.sub("#", "",token)
        
        token = re.sub("(.)\1{1,}", "\1\1" , token)
    
        if tag.startswith("NN"):
            pos = 'n'
        elif tag.startswith('VB'):
            pos = 'v'
        else:
            pos = 'a'

        lemmatizer = WordNetLemmatizer()
        token = lemmatizer.lemmatize(token, pos)

        if len(token) > 0 and token not in string.punctuation and token.lower() not in stop_words:
            cleaned_tokens.append(token.lower())
    return cleaned_tokens

# %%
from nltk.corpus import stopwords

# %%
stop_words = stopwords.words('english')

# %%
print(remove_noise(tweet_tokens[0], stop_words))
# Out:
# ['followfriday', 'top', 'engage', 'member', 'community', 'week', ':)']

# %%
positive_tweet_tokens = twitter_samples.tokenized('positive_tweets.json')

# %%
negative_tweet_tokens = twitter_samples.tokenized('negative_tweets.json')

# %%
positive_cleaned_tokens_list = []

# %%
negative_cleaned_tokens_list = []

# %%
for tokens in positive_tweet_tokens:
    positive_cleaned_tokens_list.append(remove_noise(tokens, stop_words))

# %%
print(positive_cleaned_tokens_list)
# Out:
# [['followfriday', 'top', 'engage', 'member', 'community', 'week', ':)'], ['hey', 'james', 'odd', ':/', 'please', 'call', 'contact', 'centre', '02392441234', 'able', 'assist', ':)', 'many', 'thanks'], ['listen', 'last', 'night', ':)', 'bleed', 'amazing', 'track', 'scotland'], ['congrats', ':)'], ['yeaaaah', 'yippppy', 'accnt', 'verify', 'rqst', 'succeed', 'get', 'blue', 'tick', 'mark', 'fb', 'profile', ':)', '15', 'day'], ['one', 'irresistible', ':)', 'flipkartfashionfriday'], ['like', 'keep', 'lovely', 'customer', 'wait', 'long', 'hope', 'enjoy', 'happy', 'friday', 'lwwf', ':)'], ['second', 'thought', '’', 'enough', 'time', 'dd', ':)', 'new', 'short', 'enter', 'system', 'sheep', 'must', 'buy'], ['jgh', 'go', 'bayan', ':d', 'bye'], ['act', 'mischievousness', 'call', 'etl', 'layer', 'in-house', 'warehouse', 'app', 'katamari', 'well', '…', 'name', 'imply', ':p'], ['followfriday', 'top', 'influencers', 'community', 'week', ':)'], ['love', 'big', '...', 'juicy', '...', 'selfies', ':)'], ['follow', 'follow', 'u', 'back', ':)'], ['perfect', 'already', 'know', "what's", 'wait', ':)'], ['great', 'new', 'opportunity', 'junior', 'triathletes', 'age', '12', '13', 'gatorade', 'series', 'get', 'entry', ':)'], ['laying', 'greeting', 'card', 'range', 'print', 'today', 'love', 'job', ':-)'], ["friend's", 'lunch', '...', 'yummmm', ':)', 'nostalgia', 'tbs', 'ku'], ['id', 'conflict', 'thanks', 'help', ':d', "here's", 'screenshot', 'work'], ['hi', 'liv', ':)'], ['hello', 'need', 'know', 'something', 'u', 'fm', 'twitter', '—', 'sure', 'thing', ':)', 'dm', 'x'], ['followfriday', 'top', 'new', 'follower', 'community', 'week', ':)'], ["i've", 'hear', 'four', 'seasons', 'pretty', 'dope', 'penthouse', 'obvs', 'gobigorgohome', 'fun', "y'all", ':)'], ['yeah', 'suppose', 'lol', 'chat', 'bit', 'x', ':)'], ['hello', ':)', 'get', 'youth', 'job', 'opportunities', 'follow'], ['💅', '🏽', '💋', ':)', 'see', 'year'], ['thank', ':-)'], ['hope', 'rest', 'night', 'go', 'quickly', '...', 'bed', '...', 'get', 'music', 'fix', 'time', 'dream', ':)'], ['spiritual', 'ritual', 'festival', 'népal', 'beginning', 'line-up', ':)', 'leave', 'line-up', 'see', '...'], ['hey', 'sarah', 'send', 'us', 'email', 'bitsy.com', "we'll", 'help', 'asap', ':)'], ['lols', ':d'], ['kik', 'hatessuce', '32429', 'kik', 'kikme', 'lgbt', 'tinder', 'nsfw', 'akua', 'cumshot', ':)'], ['come', 'house', ':)'], ['nsn_supplements', 'effective', 'press', 'release', 'distribution', 'result', ':)', 'link', 'remove', 'pressrelease', 'newsdistribution'], ['hi', 'bam', 'follow', 'bestfriend', 'love', 'lot', ':)', 'see', 'warsaw', '<3', 'love', '<3', 'x46'], ['everyone', 'watch', 'documentary', 'earthlings', 'youtube', ':-)'], ['follow', 'follow', 'u', 'back', ':)'], ['followfriday', 'top', 'support', 'community', 'week', ':)'], ['buuuuuuuut', 'oh', 'well', ':-)'], ['look', 'forward', 'visit', 'next', 'week', 'letsgetmessy', 'jo', ':-)'], ['make', 'u', 'feel', 'good', 'never', 'see', 'anyone', 'kpop', 'flesh', ':d'], ['good', 'girl', 'best', 'wish', ':-)'], ['great', 'enough', 'reason', 'listen', 'one', 'epic', 'soundtrack', ':d'], ['thank', 'shout', 'great', 'friday', ':)'], ['add', 'video', 'playlist', 'im', 'back', 'twitch', 'today', 'go', 'league', ':)', '1', '4'], ['would', 'love', 'see', 'dear', 'jordan', ':)', 'wait', ':)'], ['oh', 'okay', ':d', 'thanks'], ['like', 'fake', 'gameplays', ';)', 'haha', 'im', 'kidding', 'im', 'kidding', 'good', 'stuff', ':)'], ['yeah', 'exactly', ':)'], ['new', 'product', 'line', 'etsy', 'shop', 'check', ':)', 'boxroomcrafts'], ['hope', 'vacation', 'go', 'great', ':d'], ['rechargeable', 'normally', 'come', 'charger', 'u', 'buy', ':)'], ['followfriday', 'top', 'engage', 'member', 'community', 'week', ':)'], ['well', 'asleep', 'one', 'talk', 'sooo', 'someone', 'text', ':)'], ['yes', 'suppose', 'bet', "he'll", 'blue', 'fit', 'hear', 'speech', 'today', 'pity', ':-)'], ['green', 'garden', 'midnight', 'sun', 'beautiful', 'canal', 'dasvidaniya', 'till', 'next', 'visit', ':)'], ['scout ...

# %%
for tokens in negative_tweet_tokens:
    negative_cleaned_tokens_list.append(remove_noise(tokens, stop_words))

# %%
print(negative_cleaned_tokens_list)
# Out:
# [['hopeless', 'tmr', ':('], ['everything', 'kid', 'section', 'ikea', 'cute', 'shame', "i'm", 'nearly', '19', '2', 'month', ':('], ['heart', 'slide', 'waste', 'basket', ':('], ['“', 'hate', 'japanese', 'call', 'ban', ':(', ':(', '”'], ['dang', 'start', 'next', 'week', 'work', ':('], ['oh', 'god', 'baby', 'face', ':('], ['make', 'smile', ':('], ['work', 'neighbour', 'motor', 'asked', 'say', 'hat', 'update', 'search', ':('], [':(', 'sialan', ':('], ['athabasca', 'glacier', '1948', ':-(', 'athabasca', 'glacier', 'jasper', 'jaspernationalpark', 'alberta', 'explorealberta', '…'], ['really', 'good', 'g', 'idea', "i'm", 'never', 'go', 'meet', ':('], ['mare', 'ivan', ':('], ['happy', 'trip', 'keep', 'safe', 'see', 'soon', ':('], ["i'm", 'tire', 'hahahah', ':('], ['knee', 'replacement', 'get', 'day', ':-(', 'ouch'], ['relate', 'sweet', 'n', 'sour', 'kind', 'bi-polar', 'people', 'life', '...', 'cuz', 'life', '...', 'full', '...', ':('], ['pleasse', ':('], ['im', 'sure', 'tho', ':('], ['feel', 'stupid', "can't", 'seem', 'grasp', 'basic', 'digital', 'painting', 'nothing', "i've", 'research', 'help', ':('], ['good', 'lord', ':('], ['feel', 'lonely', 'someone', 'talk', 'guy', 'girl', ':('], ['assignment', 'project', ':(', 'really', '😩'], ['want', 'play', 'video', 'game', 'watch', 'movie', 'someone', ':('], ['choreographing', 'hard'], ['email', 'link', 'still', 'say', 'long', 'available', ':('], ['cry', 'bc', 'miss', 'mingming', 'much', ':-('], ['sorry', ':('], ['mom', 'far', 'away', ':('], ["we're", 'truly', 'sorry', ':(', 'safe', 'flight'], ['friend', ':('], ['oh', ':(', 'hate', 'happen', 'get', 'sad'], ['oh', 'dog', 'pee', '’', 'bag', ':-(', '’', 'take', 'newwine15'], ['doushite', ':('], ['late', ':('], ['suck', 'much', 'sick', 'plan', 'start', 'work', 'first', 'gundam', 'night', 'nope', ':('], ['2', 'dollar', ':(', '😭', '😭', '😭'], ['listening', 'back', 'old', 'show', 'know', "i'm", 'weird', 'get', 'u', 'leave', 'might', 'give', 'pale', 'imitation', ':-('], ['go', 'sea', 'massive', 'fucking', 'rash', 'body', 'painful', 'thing', 'ever', 'want', 'go', 'home', ':('], ['hi', 'absent', ':('], ['gran', 'tho', 'know', 'care', 'tell', ':('], ['cute', 'love', 'much', 'wish', 'would', 'sequel', ':('], ['busy', 'sa', 'school', ':(', 'next', 'time', 'love', 'yah', 'xx'], ['ouucchhh', 'one', 'wisdom', 'teeth', 'come', ':('], ['frighten', 'case', 'really', 'get', ':('], ['pret', ':(', 'wkwkw', 'verfied', 'active', 'forget', 'follow', 'member', 'thanks', 'join', 'goodbye'], ['´', 'get', 'chain', 'love', '´', '—', 'sentir-se', 'incompleta'], ['okay', '..', '..', ':('], ['go', 'wednesday', ':('], ['marvellous', 'thwarting', ':-('], ['awh', "what's", 'chance', '😩', 'u', 'zante', 'need', 'something', ':-(', 'x'], ["when's", 'birthday', ':('], ['bad', 'part', 'still', 'feel', 'bad', ':('], ['audraesar', 'sushi', 'pic', 'tl', 'drive', 'craaaazzyy', ':('], ['really', 'want', ':('], ['popped', 'like', 'helium', 'balloon', '..', ':-('], ['climatechange', 'cc', "california's", 'powerful', 'influential', 'air', 'pollution', 'watchdog', 'califor', '...', 'uniteblue', 'tcot', ':-('], ['sad', 'elhaida', 'rob', 'jury', ':(', 'come', '10th', 'televoting'], ['climatechange', 'cc', 'idaho', 'restrict', 'fish', 'despite', 'regional', 'drought-linked', 'die-of', '...', 'uniteblue', 'tcot', ':-('], ['climatechange', 'cc', 'abrupt', 'climate', 'change', 'may', 'doom', 'mammoth', 'megafauna', 'sc', '...', 'uniteblue', 'tcot', ':-('], ['climatechange', 'cc', "australia's", 'dirtiest', 'power', 'station', 'considers', 'clean', 'energy', 'biomass', '...', 'uniteblue', 'tcot', ':-('], ['climatechange', 'cc', "ain't", 'easy', 'green', 'golf', 'course', 'california', 'ulti', '...', 'uniteblue', 'tcot', ':-('], ['well', 'sure', 'work', 'day', 'mine', ':('], ['im', 'gonna', 'miss', 'u', 'sexy', 'prexy', ':('], ['miss', 'kindergarten', 'kid', ':('], ['hungry', ':-('], ['cant', 'find', 'book', 'keep', 'sane', ':('], ['literally', 'three', 'lounge', 'event', ':-(', 'much', 'turn', "i'm", ...

# %%
def get_all_words(cleaned_tokens_list):
    for tokens in cleaned_tokens_list:
        for token in tokens:
            yield token

# %%
all_pos_words = get_all_words(positive_cleaned_tokens_list)

# %%
from nltk import FreqDist

# %%
freq_dist_pos = FreqDist(all_pos_words)
print(freq_dist_pos.most_common(50))
# Out:
# [(':)', 3691), (':-)', 701), (':d', 658), ('thanks', 388), ('follow', 361), ('love', 336), ('...', 290), ('good', 283), ('get', 263), ('thank', 253), ('u', 245), ('day', 242), ('like', 229), ('happy', 198), ('see', 195), ("i'm", 183), ('great', 175), ('hi', 173), ('go', 167), ('back', 163), ('know', 161), ('new', 147), ('make', 145), (':p', 139), ('<3', 135), ('one', 131), ('..', 129), ('time', 125), ('hope', 123), ('us', 115), ('look', 114), ('friday', 113), ('today', 113), ('work', 109), ('morning', 101), ('nice', 99), ('please', 98), ('want', 96), ("i'll", 91), ('much', 89), ('think', 87), ('lot', 85), ('via', 85), ('would', 84), ('week', 83), ('well', 81), ('let', 81), ('really', 79), ('enjoy', 78), ('hey', 77)]

# %%
all_neg_words = get_all_words(negative_cleaned_tokens_list)

# %%
freq_dist_neg = FreqDist(all_neg_words)
print(freq_dist_neg.most_common(50))
# Out:
# [(':(', 4585), (':-(', 501), ("i'm", 343), ('...', 332), ('get', 325), ('miss', 291), ('go', 275), ('please', 275), ('want', 246), ('like', 218), ('♛', 210), ('》', 210), ('u', 193), ("can't", 180), ('time', 160), ('follow', 156), ('sorry', 149), ('one', 149), ('see', 145), ('day', 144), ('love', 142), ('much', 139), ('know', 137), ('good', 135), ('really', 133), ('work', 130), ('im', 128), ('feel', 125), ('sad', 125), ('still', 124), ('back', 121), ('make', 118), ('..', 108), ('today', 108), ('come', 107), ('need', 106), ('think', 102), ('followed', 102), ('say', 94), ('wanna', 94), ('oh', 92), ('wish', 91), ('sleep', 91), ('bad', 89), ('look', 81), ('snapchat', 79), ("i've", 77), ('thanks', 77), ('people', 75), ('watch', 73)]

# %%
def get_tweets_for_model(cleaned_tokens_list):
    for tweet_tokens in cleaned_tokens_list:
        yield dict([token, True] for token in tweet_tokens)

# %%
positive_tokens_for_model = get_tweets_for_model(positive_cleaned_tokens_list)

# %%
negative_tokens_for_model = get_tweets_for_model(negative_cleaned_tokens_list)

# %%
import random

# %%
positive_dataset = [(tweet_dict, "Positive")
                     for tweet_dict in positive_tokens_for_model]

# %%
negative_dataset = [(tweet_dict, "Negative")
                     for tweet_dict in negative_tokens_for_model]

# %%
dataset = positive_dataset + negative_dataset

# %%
random.shuffle(dataset)

# %%
train_data = dataset[:8000]
test_data = dataset[8000:]

# %%
from nltk import classify

# %%
from nltk import NaiveBayesClassifier

# %%
classifier = NaiveBayesClassifier.train(train_data)

# %%
print("Accuracy is:", 100*classify.accuracy(classifier, test_data))
# Out:
# Accuracy is: 99.4

# %%
print(classifier.show_most_informative_features(100))
# Out:
# Most Informative Features
#                       :) = True           Positi : Negati =   1875.8 : 1.0
#                       ff = True           Positi : Negati =     28.2 : 1.0
#                 follower = True           Positi : Negati =     26.1 : 1.0
#                      bam = True           Positi : Negati =     22.9 : 1.0
#                      sad = True           Negati : Positi =     20.6 : 1.0
#                      x15 = True           Negati : Positi =     19.7 : 1.0
#                      ugh = True           Negati : Positi =     16.4 : 1.0
#                 followed = True           Negati : Positi =     16.3 : 1.0
#                   arrive = True           Positi : Negati =     15.8 : 1.0
#                     glad = True           Positi : Negati =     14.9 : 1.0
#                     cool = True           Positi : Negati =     13.8 : 1.0
#                goodnight = True           Positi : Negati =     11.6 : 1.0
#                     miss = True           Negati : Positi =     11.2 : 1.0
#                   hungry = True           Negati : Positi =     11.0 : 1.0
#                    happy = True           Positi : Negati =     10.8 : 1.0
#               definitely = True           Positi : Negati =     10.3 : 1.0
#                   invite = True           Positi : Negati =     10.3 : 1.0
#                      via = True           Positi : Negati =     10.2 : 1.0
#               appreciate = True           Positi : Negati =     10.2 : 1.0
#                  welcome = True           Positi : Negati =      9.5 : 1.0
#                    thank = True           Positi : Negati =      9.4 : 1.0
#                     sick = True           Negati : Positi =      9.3 : 1.0
#                   friday = True           Positi : Negati =      8.5 : 1.0
#                       :( = None           Positi : Negati =      8.5 : 1.0
#                   ignore = True           Negati : Positi =      8.4 : 1.0
#                    stage = True           Negati : Positi =      8.4 : 1.0
#                 pleasure = True           Positi : Negati =      8.3 : 1.0
#                   excite = True           Positi : Negati =      8.3 : 1.0
#                     tire = True           Negati : Positi =      8.2 : 1.0
#                    great = True           Positi : Negati =      8.2 : 1.0
#                     blog = True           Positi : Negati =      8.2 : 1.0
#                    enjoy = True           Positi : Negati =      7.9 : 1.0
#                  awesome = True           Positi : Negati =      7.9 : 1.0
#                    didnt = True           Negati : Positi =      7.8 : 1.0
#                     sell = True           Negati : Positi =      7.7 : 1.0
#             ubericecream = True           Negati : Positi =      7.7 : 1.0
#                    click = True           Positi : Negati =      7.6 : 1.0
#                      thx = True           Positi : Negati =      7.6 : 1.0
#                    brain = True           Positi : Negati =      7.6 : 1.0
#                  perfect = True           Positi : Negati =      7.4 : 1.0
#                       aw = True           Negati : Positi =      7.3 : 1.0
#                      eat = True           Negati : Positi =      7.0 : 1.0
#                      bro = True           Positi : Negati =      7.0 : 1.0
#                 congrats = True           Positi : Negati =      7.0 : 1.0
#                    smile = True           Positi : Negati =      6.8 : 1.0
#                     kill = True           Negati : Positi =      6.6 : 1.0
#                    cream = True           Negati : Positi =      6.6 : 1.0
#                 follback = True           Positi : Negati =      6.6 : 1.0
#                      ive = True           Negati : Positi =      6.4 : 1.0
#                    leeds = True           Negati : Positi =      6.4 : 1.0
#                    upset = True           Negati : Positi =      6.4 : 1.0
#                        – = True           Positi : Negati =      6.3 : 1.0
#                     cold = True           Negati : Positi =      6.2 : 1.0
#                     poor = True           Negati : Positi =      6.1 : 1.0
#                wonderful = True           Positi : Negati =      6.1 : 1.0
#                     hurt = True           Negati : Positi =      6.1 : 1.0
#                    sorry = True           Negati : Positi =      5.9 : 1.0
#                      idk = True           Negati : Positi =      5.9 : 1.0
#                     huhu = True           Negati : Positi =      5.8 : 1.0
#                  amazing = True           Positi : Negati =      5.7 : 1.0
#                    amber = True           Negati : Positi =      5.7 : 1.0
#                 infinite = True           Negati : Positi =      5.7 : 1.0
#                   vidcon = True           Negati : Positi =      5.7 : 1.0
#                    kikme = True           Negati : Positi =      5.7 : 1.0
#                 horrible = True           Negati : Positi =      5.7 : 1.0
#                  product = True           Positi : Negati =      5.6 : 1.0
#                brilliant = True           Positi : Negati =      5.6 : 1.0
#                   coffee = True           Positi : Negati =      5.6 : 1.0
#                     scar = True           Negati : Positi =      5.4 : 1.0
#                      mum = True           Negati : Positi =      5.4 : 1.0
#                      ice = True           Negati : Positi =      5.4 : 1.0
#                     nice = True           Positi : Negati =      5.2 : 1.0
#               bestfriend = True           Positi : Negati =      5.1 : 1.0
#                   lovely = True           Positi : Negati =      5.1 : 1.0
#                       hi = True           Positi : Negati =      5.0 : 1.0
#                       bc = True           Negati : Positi =      5.0 : 1.0
#                   madrid = True           Negati : Positi =      5.0 : 1.0
#                     lmao = True           Negati : Positi =      5.0 : 1.0
#                     data = True           Negati : Positi =      5.0 : 1.0
#                     foot = True           Negati : Positi =      5.0 : 1.0
#                     damn = True           Negati : Positi =      5.0 : 1.0
#                   cancel = True           Negati : Positi =      5.0 : 1.0
#                       rn = True           Negati : Positi =      5.0 : 1.0
#                   driver = True           Negati : Positi =      5.0 : 1.0
#                       tl = True           Negati : Positi =      5.0 : 1.0
#                     isnt = True           Negati : Positi =      5.0 : 1.0
#                        � = True           Negati : Positi =      5.0 : 1.0
#                  retweet = True           Positi : Negati =      5.0 : 1.0
#                 response = True           Positi : Negati =      5.0 : 1.0
#                    brand = True           Positi : Negati =      5.0 : 1.0
#                     folk = True           Positi : Negati =      5.0 : 1.0
#                      men = True           Positi : Negati =      5.0 : 1.0
#               collection = True           Positi : Negati =      5.0 : 1.0
#                     tgif = True           Positi : Negati =      5.0 : 1.0
#                     ball = True           Positi : Negati =      5.0 : 1.0
#                    hello = True           Positi : Negati =      5.0 : 1.0
#                beautiful = True           Positi : Negati =      5.0 : 1.0
#                   thanks = True           Positi : Negati =      5.0 : 1.0
#                      pls = True           Negati : Positi =      4.9 : 1.0
#                   havent = True           Negati : Positi =      4.6 : 1.0
# None
